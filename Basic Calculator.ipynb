# %%
#PYTHON PROJECT: BUILDING A BASIC CALCULATOR

def add(a,b):
#This function is going to add the 2 paramters inputed by the user, and then print out the answer"""
    answer=a+b
    print(str(a)+"+"+str(b)+"="+str(answer))
    
def sub(a,b):
#This function is going to subtract the 2 paramters inputed by the user, and then print out the answer"""
    answer= a-b
    print(str(a)+"-"+str(b)+"="+str(answer))
    
def mult(a,b):
#This function is going to multiply the 2 paramters inputed by the user, and then print out the answer"""
    answer= a+b
    answer= a*b
    print(str(a)+"*"+str(b)+"="+str(answer))
    
def div(a,b):
#This function is going to divide the 2 paramters inputed by the user, and then print out the answer"""
    answer= a+b
    answer= a/b
    print(str(a)+"/"+str(b)+"="+str(answer))
    
while True:  #The while loop is added to let the user keep calculating until she doesnt want to anymore
    
    print()
    print("This is Sommie's Calculator here for your service. What operation do you wish to perform: ")
    print("A. Addition")      #prints out the 5 operations the calculator can perform
    print("B. Subtraction")
    print("C. Multiplication")
    print("D. Division")
    print("E. Exit")

    choice=input("input your choice: ")   
    #initializing the choice variable to accept inputs lets the user select what operation he wants performed based on the options above.

    if choice=="a" or choice=="A":
        print("ADDITION")
        a=int(input("input first number: "))
        b=int(input("input second number: "))
        add(a,b)

    elif choice=="b" or choice=="B":
        print("SUBTRACTION")
        a=int(input("input first number: "))
        b=int(input("input second number: "))
        sub(a,b)

    elif choice=="c" or choice=="C":
        print("MULTIPLICATION")
        a=int(input("input first number: "))
        b=int(input("input second number: "))
        mult(a,b)

    elif choice=="d" or choice=="D":
        print("DIVISION")
        a=int(input("input first number: "))
        b=int(input("input second number: "))
        div(a,b)

    elif choice=="e" or choice=="E":
        print("program ended")
        break  #breaks the while loop 
        
        print()  #for extra spaces
        print()
# Out:
# This is Sommie's Calculator here for your service. What operation do you wish to perform:
# A. Addition
# B. Subtraction
# C. Multiplication
# D. Division
# E. Exit
# input your choice: a
# ADDITION
# input first number: 2
# input second number: 3
# 2+3=5
#
# This is Sommie's Calculator here for your service. What operation do you wish to perform:
# A. Addition
# B. Subtraction
# C. Multiplication
# D. Division
# E. Exit
# input your choice: e
# program ended
